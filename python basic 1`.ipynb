# %%
print("Hello World")
print("Welcome to PDA")
# Out:
# Hello World
# Welcome to PDA

# %% [markdown]
# indentation

# %%
print("I have no indentation")
print("I have indentation")
# Out:
# I have no indentation
# I have indentation

# %% [markdown]
# Taking input

# %%
s="ABC"
age=25
p="India"
print(s,age,p)
# Out:
# ABC 25 India

# %% [markdown]
# Python Variables

# %%
x=55.7
s="Hello"
print(x)
print(s)
